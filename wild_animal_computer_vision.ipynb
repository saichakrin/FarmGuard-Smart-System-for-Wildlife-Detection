# %% [markdown]
# <a href="https://colab.research.google.com/github/Agewerc/wildlifeComputerVision/blob/master/wild_animal_computer_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An Algorithm for Wildlife Animals Identification
#
# In notebook we will be working with the Oregon Wildlife [dataset](https://www.kaggle.com/virtualdvid/oregon-wildlife/kernels) created by [David Molina](https://www.kaggle.com/virtualdvid) with a google scrapper.It constains about 14.000 pictures of 19 different wildlife species such as Deers, Cougars, Grey Wolfs and so on.
#
# Wouldn't it be fun to have a app that tells you what animals are you observing in the nature when you are camping or hiking? This project may be a first step to create this app.
#
# We aim to generate a model that scans an image and identify what is the animal species on the screen. To achieve this goal we will make use of **Convolutional Neural Networks.** <br><br>
#
# ## How does a Convolutional Neural Network function ?
#
# [deep.ai](https://deepai.org/machine-learning-glossary-and-terms/convolutional-neural-network): CNNs process images as volumes, receiving a color image as a rectangular box where the width and height are measure by the number of pixels associated with each dimension, and the depth is three layers deep for each color (RGB). These layers are called channels. Within each pixel of the image, the intensity of the R, G, or B is expressed by a number. That number is part of three, stacked two-dimensional matrices that make up the image volume and form the initial data that is fed to into the convolutional network. The network then begins to filter the image by grouping squares of pixels together and looking for patterns, performing what is known as a convolution. This process of pattern analysis is the foundation of CNN functions.<br><br>
#
#
# ![CNN](https://miro.medium.com/max/2510/1*vkQ0hXDaQv57sALXAJquxA.jpeg)
#
#
# ### Libraries
# - numpy (Linear Algebra)
# - pandas (Data Manipulation and Analysis)
# - glob (File Manipulation)
# - os (File Manipulation)
# - regex (text patterns)
# - random (sampling data)
# - PIL (image processing)
# - Sklearn (Evaluation Metrics)
# - Pytorch (Deep Learning)
#
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 1](#step1): Import Libraries and Load the Dataset
# * [Step 2](#step2): Create a CNN to Classify Wild Animals (from Scratch)
# * [Step 3](#step3): Create a CNN to Classify Wild Animals (using Transfer Learning)
# * [Step 4](#step3): Test the model and create an Algorithm
#
# We first mount the folder on the google drive with the dataset.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# https://github.com/Agewerc/wildlifeComputerVision/tree/master

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Import Dataset and Libraries
#
# Our fist step is to import all the libraries used in this project.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
import pandas as pd
import os
import re
import random
from PIL import Image
from sklearn.preprocessing import LabelEncoder
import os
import pandas as pd
from skimage import io
import torch
import torch.nn as nn  # All neural network modules, nn.Linear, nn.Conv2d, BatchNorm, Loss functions
import torch.optim as optim  # For all Optimization algorithms, SGD, Adam, etc.
import torchvision.transforms as transforms  # Transformations we can perform on our dataset
import torchvision
from torch.utils.data import (Dataset, DataLoader)  # Gives easier dataset managment and creates mini batches
from torchvision.datasets import ImageFolder
import torchvision.models as models

# %% [markdown]
# ## Visualize the data
#
# First lets examine the files.
# - Which are the species?
# - How many pictures do we have from each animal?

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.8)

# %%
# !kaggle datasets download -d virtualdvid/oregon-wildlife
# Out:
# Dataset URL: https://www.kaggle.com/datasets/virtualdvid/oregon-wildlife
# License(s): unknown
# Downloading oregon-wildlife.zip to /content
# 100% 4.54G/4.55G [00:56<00:00, 104MB/s]
# 100% 4.55G/4.55G [00:56<00:00, 86.5MB/s]

# %%
# !unzip oregon-wildlife.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f393079cfbbc7b8be6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f3be83575a3a92d435.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f3e101456dcdac39dd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f4acd5fcab454fef8f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f4c09f2366d77e2ae6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f50d7a4e8bd196a9eb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f53e5ae3b6b216d79f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f6116e16c85f34b0b2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f71539caada8e56085.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f9bd8ffa9626adbd93.png
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f9c45486969596ebfe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/f9f0e6d8826a36958d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fabbe400da7d53f13d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fadf2323a92a1fef42.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fadf871671af43cde0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/faeb11859658a8cd77.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fafdb2d355ae2a347b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fbd44cd1d681b8604a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fbf5c87b09f722eb16.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fc08208979593f96c2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fc7f87bf237565bc7b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fc8d398eb7f66d2cca.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fceb11374c57d9ae56.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fd1e86bd2f225583dc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fd41cda68ffaa73194.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fd5d76e66e37bad537.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fdc9a00ed3ad893970.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fdcebb9e95ab651c98.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fe1ee1003c582f9cde.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/feaab75f9d1f7a70bb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/ff2f6208d2ea0c456a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/ff53dc3ae36f62c253.jpg
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fff34f6e9b8b19b977.JPG
#   inflating: oregon_wildlife/oregon_wildlife/gray_wolf/fff46f2cf95245b3c5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0107b77c5f8ecfa7e0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/01b2a0abc51983d03d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/01d7965abfb9f7b83f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/02c12ec4b15417a66e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/02d52818072398a98f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/037e43df03de039565.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/03a6d17d05c8663528.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/03d04f50ab8fa97017.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0455ce72a6b1a7c0fb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/049885759987a80300.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/04ce77e5557bec5917.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/051c69ef4466be2f26.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/055f1abcd46993e61d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0567cabb31afaa983c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/061c42163adb4f9c77.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0672114e18d78fd595.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0690c150f329f67db6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/080a98141e8885c340.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/085e6cebf588f2e4ea.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/086d49809df194b44c.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/09053a24821ce94321.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/09489202c79f966c31.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/095a112927bdc6411b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0b43bad4c198c42857.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0bdafccb2f6eca31df.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0c0a3f135848d16aeb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0c9b17ec50dfd32a09.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0d69cf69a150333b40.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0d7accccfefe38880a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0dbe154799f5576340.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0ef5a64b79a4d56c69.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/0effd6ea5763811fc9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/102072ebd220f5abc4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/102718d108e48e2fea.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/108e2a73f233d6c96b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/10b54ca97060c3442c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/11ddd4d2f97f4dafee.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/122d30227bcedc1e3b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/126707089329e8070f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1359dcc1f140b0c99e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/13ad27aced5187ffe3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/13b476a8db33637da5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/13ee087dfcc2c9af1c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/14079b5fcc14123f64.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/14158fdd85baa98e77.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/14af9d963aefe9837f.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/14fafcc64304e51b3c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/15c8374e20311cb4bc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/16162b6d5bb684860c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/16795d0f8b6cbb1e6a.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1713aa597e57f05b6d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/173ee7ec3da2602b36.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/174e499d641df0c009.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/18d9ebdbd37c0d11ed.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1a56abffc07763470c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1ab8b1aa0943b0709f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1ad1255cccc4a5712c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1afc04a26d6599eb65.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1baad4ff2e3e7a4342.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1bdea4774d47255790.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1c5cb4e950e45c3925.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1c740dd361ffdaa825.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1d4206cab64c6c3f9c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1d84828e13ee698e98.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1dfcb0caf453b1ee84.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1e1cf5b79eb08de543.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1ea4c4f39fd6b39198.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1ecc33e425c53181b1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1efb301eaef6f23780.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/1f409d162aa03d52d6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2000579337e859e145.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/202f3e6a4c90a33c75.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/204870dc414c13c68a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/20a6f9d68258763750.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/20cc9f02b5fa12d372.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/212a987ca465d8f141.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/21a8a1a4bf6da97034.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/233fd33d77f6fc274b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/236981b3925937cc7c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/237e5e11fd0db566cf.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/23880e09fd65a56794.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2444240ee1d91488cd.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/24bc87711d6e06ead6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/259658ac0d55e0c5cd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/262e6751b0bcdde6bf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2695673695e1537149.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/275cf131eff58cb31a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2768dac8cff26072d3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/28ae4d9baa2b7d3ad5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/291808f5fa31bc5a56.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/29264144a280f06413.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2993c242e0d27513e5.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/29bf7363f06c58fa52.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2a60b85b6a915c52eb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2a9be1ae679101cec2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2ad84a6d9ef4c068bc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2b8dad2f3a7bee82e3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2ba0c5cc29e2cdf541.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2c6def8c0cd6ba62ed.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2c823eedbf252d9eb5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2ca76d67a4753f2f9e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2d85d75cfe4d1e39e3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2d8d0bec6b999306d5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2daa1f906acca72bf3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2e39c43a42099f9bd9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2e84400ba62adb3aed.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/2fe70f6ec9ccc108f8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/305f2b35eddc27f26b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/307a34d145c3d8fbe9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/30f865470734117e4a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3105f534854eed81cc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/31881e4a6ca38b9d92.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/32488a00c99b4145e8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3391c3286aea8c3000.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/33c2cdbbb8ab189a27.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/33c81aabb348140484.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/34281ed375b1e47228.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/342ab68bd0880607b8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3492dcdf476bf3cbc1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/34b47dce42cb211c3d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/34c2d5b8142083f7f2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/351d18176ee9ec372f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3534bece404d0715b6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/35552e008310cc7220.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/357634e0ab40f762aa.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/35c0a0165c42410d0c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/36b66b28a8e05bb695.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/36fbc91dfa9f931de2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3865438267ae4fbb2b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/38b87f80faf45bff68.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/397587ddbf8c6752fc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3a24f52e39ecb905d4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3ae6530bc83c216ad3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3b6a52c5de4815ab2e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3bc6e3c6feeccd2bf4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3c2781ceba6cb042d9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3ca2927ab043360c62.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3cb4c8fd7956c2a8c3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3ce37e06354f3022fe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3de913f0118b602c62.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3e13e4ddcce347d5a9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3ef26afdeaa4fe3bb6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/3f35188a9d4cda0c31.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/40317a3bd178abdc7c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/418f90dbc9714f969a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/42320472f7e8457b52.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4270f5dcac6d7ea986.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4314774f022689b0b3.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/442b70202c54a03c77.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/450310946ad39095d5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/45b9ed32a89598d508.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/45f57294e0ee686b32.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4608678dd0b455dd09.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/473829f9a7c05cdf59.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/47a47376cd5292bc1d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/47a94766185b3ad9bf.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4970d7775bf53f6eb6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/49a6c4d98808dc1399.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/49d56a443c9e9883cc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4b782f7ca998b5eb46.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4c01a6dd7ab5c2bcba.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4c0b016af03965090f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4c2d9d9c422b3fb7fa.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4cfc619dceef8e4108.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4d08f1abc4f1b78a51.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4d420353a400a3d87f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4d6eb889c67d9c06f7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4e18b816fd987ce9c0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4e5df25c87aa6c7503.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4eff15b581bce6efcf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4f313d52ccf7fc5992.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4f3c4ab6743d0f0ebe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4f89a3e46ad8e982ed.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/4f9bd93de99a89590e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/504c970e66c8f313c0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/505443354726ad82c4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/50b1c4108924a74560.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/514a6739c9d5ac82ae.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/517b7d4caf3419c500.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/518fc6858cdf00ce78.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/51901436647dd28450.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/51b9f0bc184c187153.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/51c6b448c22e04f4e9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/52ac2ae8f26c069339.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5304fa2955e09826a1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5340c005d1f8346240.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5376b3812e7aa7e5ee.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/53b701874030ebabff.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/53b9e348bd748618a3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/543f64501e1ec919a5.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/545fbf8963b102ea30.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/557c2680f6d5c6daff.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/560c76fc24b6bc1590.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5757143c14bd8ccef9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/581f91b9c31a5f109f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/586e0f0a2dc181ed59.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/58ecb326c63d907dcd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/595d1da5f8836c1a59.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5a487ae887ea2dd291.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5a79b03ef8bf7b4956.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5ade80f170c9cff502.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5ae85a548b888ea6a9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5af1a4f3eb8ab8bce5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5b7e1899ebf3f10dc3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5b959b7bb631abc2b9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5c29f9f5d61e03cceb.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5e19a03d74589f5ac0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5ea1965bbff0c93ed5.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5efeb98e623e302d1c.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/5f2ad55d33232cdace.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/600cc10aa59d3bcf85.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/610cb8c7b3a5e43de4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/613735f5f847d33560.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6188cfd22aec11de54.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/62a071f6bb2277ea1e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/62b80557fa379e09b0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/62c9d3ee706db1bbb4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6303fe6f4d01f72054.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/632fbaecdf0270394e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/638a735e3a320ed0ed.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6435908f9536655175.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/644c97b7edc78e3bb9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/64c549d4e87925f9ad.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/650944a50a009f9326.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/65ef2965e557e71e74.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/66a244a70a45419d56.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/674ba410814cd71ce5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/67c2b06eaad2547e3d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/67e20d5a5f08dacaa3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/68af9601287bf7025a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/69f5f71b4c99f19fef.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/69fe0edf19a036616c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6aa1905b39ea04c32f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6b10684cfc8f87837f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6b4fe8095cfe517ae5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6c2bac6a7a40359367.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6c39ccb941367f82f3.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6c924dacb58f9cf5f6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6db8c49cab0ff6b507.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6dc2e32ef91eae65af.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6de51f737736574966.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6e17b4862a927e81af.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6e4a067fc23f7f9416.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6e8a7971f25fd8885c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6ee433531485fd1fc5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/6ffb7a380b0147f4e1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7031d17a858bf2c2c4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7063012378133bcb26.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/706b645df2f417dbca.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7079209e898161868a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7079857b9f4caf8440.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/714ca0f9b2b3d8c0a7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/717031b754fc67da72.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/722328deca0f4d9a83.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/72809bfbb36acfe30c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/72a10966435e2298e4.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/72acc425cd4455bb76.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/72c2b9ec3055f94698.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/72f2015eedbcd50fac.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/730038fcf38b2a22df.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/739d2e69eff511e42d.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/745a49be969c60aaff.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/74c8b8f26a8b177a2c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/74f670b6c209170d43.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7595743e5360edadc3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/75d4b13120a6209871.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/76d16719860b377cac.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/76f3bc87330e513b22.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/777e3b390a7d81dece.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/78a667bf9987288049.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7af25151d7cf64bd29.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7bed91d3897d9dd42d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7bf221e5070ed0888a.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7cdb134ce1cf39adfa.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7d5044b0822399e66c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7d6e4326b864558313.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7de719e01747287020.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7e1c00c78370f9f04b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7e5960383fd3222065.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7f65789d3a05e7e16f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/7fb07129e9198b1543.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/80344958148270e1f4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/804dd772ea7c9a82a1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/80f149f7db4f7f6d21.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/814445c3e9e71cc239.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/82834010ddae23dfb3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/82ccee5bf4907722cd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/831ac75cad5a827887.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/832230ac558dfa91ab.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8337144b9dfd31d9ec.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/834b9a31abf76d5fd6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/837438def170ba5afe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/83b256b2344896f4db.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/83b626e3da2f7c99ff.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/84499002ec640b6b92.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/85f9e363a4539ccdc1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/865009d7678c1fee69.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8668d3fa611d4e683a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/86ce8c9578f097698f.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/86fe89d90e85b37fda.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/872a2ad4c523ef4422.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/875148bab674eb4be5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/878ffb87ecbcd4becd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/87970e5fb88b16613b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/87ca33dd7b3be93560.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/87f564cdc844f5cbb6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/88e37096dbdef3a2f6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/88e3cf2e722d448a6e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8a4d3f920ac8734e95.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8aaaab3a636fd9c2d3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8b056daa2ad2853559.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8b39b34484847fc871.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8bf9ecf2124509d58f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8c385285f5f4b2360c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8c3e090eb6c40ca38e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8dafeca9d44164a507.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8e4185d9e6a17641e0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8e41f9118d5d99c9cd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8eca247f5422a6f3fc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8f14f182340745477e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8f6252aa6e2efd882f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/8fe71ed78bd9544d42.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/90029e4db4a7285e93.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/90ab3d3585ecb0ff13.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/90dff54d1ca95605bb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/91e8dd6c9bcb5ad4f3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/91ec49a4e3f750eeb0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/920df65b3b6f09d1a0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/92668ddf4ed841204e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/937dcc266c71f447ac.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/939a59f62951b674f1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/94b3562025a57b03b3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/95dae51bc2c931d2e0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9638d203b5be212e24.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/966a674ae3d5d792bd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/96e92261454a04836a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/97068336fc5183f868.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/97a44ee931c2f20fa6.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/97afb5cb6b14356856.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/97ea449df8cba481be.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/97f65334d0ff04232c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/985ae4f142194343b4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/99481b56abe673d141.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9a7ebfaba507ab762f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9a8d4255d46f4c84e0.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9ab2d1c19fddb56a82.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9aee8277570ab0347c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b03d3da41809a2115.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b1b2fb9b7c6fcd43d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b3f83f1679a37f41e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b46c7402036872577.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b861ac864c8fd67a5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9b8ea3c23f50de398d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9bbcbc1cdb45ab5de9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9be265caac03ad438e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9c2252949a2f09b4c8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9c26284014719dc219.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9c747d167765d63076.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9c8b3a9bcde1f0d767.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9d8c8c78f8e66a798e.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9dc93fe8d050578401.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9e6481aa2b110b2f08.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9e6e03d3dc8d09f445.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9ee48fde9653710c3d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/9eeb546871c0831e24.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a07134ad46f96fb733.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a08f2fe2440044e740.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a094b2f76d0476881c.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a0fd4980ebbdf30278.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a1539bc7ad0e0ab5cf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a1dc0b646db7b03adf.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a2480688af451c9a1c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a25ae188208f2fad3e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a3b11569b631d1b00c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a40fbf35f5f602f15f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a439ea8641350e9599.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a4a4499e9aaf3c9497.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a4c687a1942f007e53.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a4cf62c9e0a240872d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a500732cc7e909de90.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a527d5ff09d5df27c9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a55613f16901760351.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a56e02f69d22c02fcf.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a645e2b851b02b61ae.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a6d5686c986a84bc60.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a6ed30761a69a0dfa5.gif
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a6f827d2fdfba698eb.gif
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a73a37d919a2860419.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a73d4493339a15bd88.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a7ed5b06b2194ea341.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a951167f6ab1835b04.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a9e1681475dc7d1fd4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a9eb6da88184d96176.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/a9f0a08bda285c91f9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/aa0e7a530272a6bcaf.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/aaceaf1020873e1ba0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/abab55fa3c8de693b1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/abd7a9a32d8f25e929.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ac08544765e4dc9cab.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ac1efa03fe1fb948b8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/acaaac935a4afcc48f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/acf4a64e54820924e9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ad1398d1c184fdbb91.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ae66cecd29e8003f56.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/af4a4cc9c0bd190a10.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/af86871d9adfee8dee.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/afd32377a6c08f4f7b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b07690be5b4b6d5d7a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b0bb5792c2969853ea.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b0f9c46041234f4897.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b167e8c03ad2c5defe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b1ca3983770f084c78.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b327c92d21bb99e5b3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b3898726dd37bca8cd.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b4506174214fe19100.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b48966262b0266e1cf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b5863bb22cb31cdb39.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b665f91c22f07c267e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b6825a9cc1388790e0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b68b0e4b89d7156204.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/b72dd6ee5a556de263.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bb57147845cb6e5522.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bb7d03d1ca1dec66b3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bba3097ee30ad7d783.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bc04f2d4073ba28d8f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bd0df5f2776cbc20a9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bd0f15a38f0ac64d2e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bd43b659c852702c3c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bdcc87496f7164923e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bdf328245828606500.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/be6969539b0485a163.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bf182884f18a3b7d31.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bf6f99c29cfc67137a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/bf71993259c7cee71b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c0cbfef849c8766eca.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c0de3d6c2ffe07de91.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c0fe2079890e9b9048.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c1b6b47af4d140a3bc.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c1dc6d30b4b34f1cd4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c1fd2346eafc2b1550.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c214a3ee3e11ac648c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c24133a4cc24497daf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c2b60772c6f3d3cb0d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c342363514225fefba.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c368067eb8068fe600.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c39e29164cbc283a28.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c510016635d2435d9a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c5ee29e48eb39bbad0.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c60e8967a755b52f44.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c610b0997fadfe9421.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c8931eed6e7c5ddd1a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c9d858fb9afb89eebd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/c9ddb800fed767a415.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/cb2a41290d758bab76.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ccbadd2a124b550dc9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ccdecefe481e045cd1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/cece9c3b551c614719.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/cf250a2a1292b2c89c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/cfda1ab48ded9c06ee.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d01aeff92058a31123.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d0c29d485e9c14760c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d114b907d061b3156c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d15379e8c5c0e02d2b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d21123643d04464571.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d2750001700276b61a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d29a9b000c32ab40dd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d29ffa32a3e78daac9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d2e1db0a2386abe79c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d2e5043172200453c8.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d3385b43e6f96ec25e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d3f58f8b2b795eab1b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d40293fe52fe68a22a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d500002aa315f7d4b1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d51fe3e1b939dec6c2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d7063cf03f441795e2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d72307533dc7861bfd.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d760726d900693f1cc.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d7679313b30cc5c746.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d7c64a155e835a275b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/d99c553f4eb04eaae3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/da66c4c1f68be65aad.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/da73692025e0aae50c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/da81eeb82dbc38f686.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dabfa8d4a401d5216a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/db53956a3891986161.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/db5f4282df5bc7fd77.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/db6d8b0d72aa5bfd72.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dbf13a86ffc9f32d39.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dc223450129053a23b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dd45219b2bff36b911.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dd50e757597763b0f3.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/dd521efc5b495eb7d2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ddab3cf30739522ee1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/ddb8d90c69cb7e8407.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/de2433fef11433216f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/de476b820e50546d64.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/df3f3d429a58fb806a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/df5bb11e2fc71db3a2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/df6252567210533f79.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/df73f56703c4fd5116.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e000f28088d465218f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e03161adc3b4b104a0.JPG
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e05e3d43af46c9f7e7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e232139db301ae2379.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e275a770550c5f1beb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e2a370aa4ba9ba8e18.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e3405a8ba2f7f8fea8.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e425e78e889308a2ec.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e514f15218f1dc89e7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e5394accc87da63312.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e5e41d9d33b55e6a74.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e601f09b58af05d287.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e64b153f25b19caba4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e681ddefd784b80412.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e6c4427d25432fd33c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e73f424eee83be88bf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e75dba9d25386a8b2e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e7a815ef92c37c9227.png
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e7adb6cc63b4ad3fbf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e7b7a240effcb91b35.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e841a67cf211b1905a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e844d113e07b8c28a6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e85f2581ff1f22e98a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e8f559ece342f01b0e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/mountain_beaver/e92a68b4cf781c5e52.jpg
# ...
#   inflating: oregon_wildlife/oregon_wildlife/seals/0585ad25667f1e6e9b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/059541822b09df8755.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/05c503ee2dff324e12.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/05c6bc0783958ee145.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/063af6f9ed890f114a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0677b6d245fb116096.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/07fbea3bd04c42f6c1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/089f0003d49314ef56.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/08d372844d3801897c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0900b045ab771c1dec.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/093212d9cbe80a2dc5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0944d43ed10a2e109e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/099673153da84b8076.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/09c3699f00cb38b631.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0a99675e426a68fc19.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/0ae7de3e0a12424844.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0be62f19e16cd8247d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0c49d9ce628eb3d74d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0d39bd5e82c2d56b9b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0ea054d7080a723ad8.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0ef029fef0644e5675.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0efb9090e73a89f4f8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0f0cac97e875a06f87.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0f1dd47011c1795f9f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0f56b82d340b036e44.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/0fd476e318db351bac.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/seals/10272923669a26d510.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/105af9c8128e77def7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/10959ff07181f3e70c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/10a60b9a80d8c94728.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1147206cd7c737f121.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/116e0c077292406153.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/118b1a29fcb743736c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/11a6f41e5d81f59e2a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/12414a4035b5e62e3f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/12bf7c011646934a5d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/130a3eec821a6c2d5b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1338256a9840b2de35.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/134f9b8a0c20ef680d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/135fa95b37895061c8.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/13680da45f2b163b69.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/seals/144f8a4cc6257f641b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/146462715afa7362a7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/14e5b0992a79d84bb7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/15dbdb87aef20a61b1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/167569c4be7e7c9fc9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/169143f59d25ee54c3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/169cff5d1cd1df5c7a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/16b409a9c1f5656afa.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1762ad4bdb5554bda5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/17a542b7aa5355d912.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/17ae8c55b6d96780cd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/17dd79154c722f2ae9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/18b347cb38d650afb1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/18d7ddf83176863fab.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/18e1012a8cd9f19d2c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/192703faa90a4fa44d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/19f2c9a83e16784556.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1a2d65102d78c118e5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1b7a2e6937b52b2deb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1b9d602aeead0c6581.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1baa4c7131543da9d0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1c36f0efc8916c185c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1ca8a75a57e6228baf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1d40c22d845e547e82.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1d7faba1028c7d1db5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1d8bd9b843438bdb79.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1ef1d71d52bb2ec129.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1f01489af2490c1b84.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1f0151615d076aeb0b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1f58c8dbdc3417fe40.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1fad5f0bc99b7ade63.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/1fe33ee8584e5f467b.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/20273b58a17e94b7b3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/207f15e0ba1f6fb969.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/20a98d921c8dbf98c4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/20eac73ee06b47ae09.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/211d8deb4f60eb8ac9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/21b383a8ded16d8bba.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/21f37e06258e5fb783.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2216baa9a1e9d203ad.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/222232402d17dd4818.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/22ac35ff15297f0c10.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/22c7abaa735df9bbb4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2403f15afc75bf8571.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/24274f091657bcd3dd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/242df5a5baee344411.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2452425c4a7a50f467.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2486c0a2136a0ab47e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/248e4cdd0c1dbb2779.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/24ab0a89bf2a68eaad.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/24f056441db410394f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/252e54f7f80b19380b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/252e921ea4d3249178.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2658827cbfc7422434.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/26a4ed2a45dfdce84c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/26afb2375f302d2c12.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/26df1fa0a0b2b2b4d6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/26f31887bba445e4d1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/272134c9573232a987.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/27551acf21ad0ef980.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/27aeaf7a3b03c04494.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/27d517eff118e6b775.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/27fe79637b89236c07.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2811dc14675dda14a0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/283c4622d5b6f980ff.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2854c279a091153304.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2896e44f3ca39cf0a4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/28db8f18fb1e0d0930.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/28e96da5f8d7235679.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/293af18adf72b12eb8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2999d5c46923559470.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2a1ba6810c64ebf5c2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2a4bee702058121d10.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2a5f2e484637df62b2.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/2ae5883624a68847de.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2b9e454217d8bb82ea.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2bb7f13f333c31f23b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2c07bcd82d7e654e58.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/2c34caeaff85ac4670.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2c686bde0008ba64a7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2d2a9dba0c29704b03.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2d336186ee78ca3d0d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2d81dbc219be1dead2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2d915983df3cf5dd69.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2defe365deda572f39.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2e80a0d99d10db1fa2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2e8a39a7f2c3c4e8e1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2e93e8f3e614c91553.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2f39247fec6981da7f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2f7ec8b8e85a8a90f2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/2fa306ed248947f165.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/3065d6b0068d1d8c37.gif
#   inflating: oregon_wildlife/oregon_wildlife/seals/30739c1526379ad0eb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/307f724fb77558dc2a.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/30ad34cc12f3477133.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/30b931cf6ef805c08e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/314d29945f2971bfa2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/31dbc41e8898cc61e6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/32cb6c9d92121df279.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3362fcc3e48e045e3b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3503923ab6d7f519c5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3518db721284ed4147.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/352cec06b547ca5050.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/357c144e239ac8c23d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/357e8cc38a79e14206.jpeg
#   inflating: oregon_wildlife/oregon_wildlife/seals/358888c806f8452d68.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/35e81ae59dbf8e1019.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/35fc19920e362c3705.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/36303b9b68b9d72fd9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/36dc827b95b2ef05d7.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/37f38b2a4995f0dd5f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/381d2aedf632f0004e.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/390ce1c78ccaf8ec5e.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/39140b42d596c6739d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3923ce8bceb626602c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3984e99de6e6a5c032.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3987b9163d16e5ef46.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3a04f8abddcfde0b22.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3a096269056c092a2c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3b2b77ac60465eb17c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3b55005875cbfdeaa4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3b5ab182d918a1b2b4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3bc7e9952134cfb334.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3c2e0cc9765a426ef0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3c39d3c9f795bb96bb.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/3cead62c2c7619d309.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3cf98daea37b340ce4.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3d019ca81e4705cfb3.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3de2799fd311df1ffa.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3e10c973986126df6d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3e15161d470e909df0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3e278231a90eb591ca.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3ea2c62b6413c2ffeb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3eb2067a97592d25bb.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3ec8ce786d0e341596.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3f90b49e88f1859baf.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3fc8d5c4f9db75d363.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/3fca5923253392f1d8.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/400f5a3d38b91a0fb5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/409f6546443f21ffe6.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/40ca9751c81cf5e634.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/41865d5cabe44fc9c0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/41c7c33f5caee35be1.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/43b1bb4ce6723bda08.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/444738817481486a5c.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/44776f6eb931f41efd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/449fc96992489216d2.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/44e5776f9cf4461249.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/457ac282e8a43bb640.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/45dac5c6b22e633ab9.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4656785eddb8310957.JPG
#   inflating: oregon_wildlife/oregon_wildlife/seals/46a6cb63a30821cd53.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/46a8fd90ed01212f03.png
#   inflating: oregon_wildlife/oregon_wildlife/seals/47870c42c503aa059d.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/47985fd0b9b72b8b8b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/47b929250382d9b8e0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/47f88aa09c9741d669.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4840835853b282449c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/484c3248e35d622ded.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/489da032dbed1fd3fe.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/49000139777f124af5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/49acb0aae6bfe3768f.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/49d028d87c1b31e9c5.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/49ec560f20f8ef31cd.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4a381cc2c96b141a1b.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4a414583f9a0043043.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4af8ed86abb2bad71c.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4c286b7fd9ec6909b0.jpg
#   inflating: oregon_wildlife/oregon_wildlife/seals/4d7d08419287b7eaf6.gif

# %%
import os

# Path to the unzipped dataset folder
dataset_path = "./oregon_wildlife"
animals_list = os.listdir(dataset_path)
animals_file_list = []

for i in range(len(animals_list)):
    # List all files in each animal's directory
    animals_file_list.append(os.listdir(os.path.join(dataset_path, animals_list[i])))
    n = len(animals_file_list[i])
    print('There are', n , animals_list[i], 'images.')

# %% [markdown]
# Apparently we have a balanced dataset,  which means we have a similar 9but not equal) proportion of images of animals from each species.
# To have a more real notion let's visualize the animals.

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torchvision import transforms
from PIL import Image

# Path to the unzipped dataset
dataset_path = "./oregon_wildlife/oregon_wildlife" # Modified path to include the nested directory

animals_list = os.listdir(dataset_path)
animals_file_list = []

# Create a list of files (images) for each animal category
for i in range(len(animals_list)):
    animals_file_list.append(os.listdir(os.path.join(dataset_path, animals_list[i])))

# Check the structure of your lists
print(animals_list)  # Check the folder names
print(animals_file_list)  # Check the image file names in each folder

# Plot settings
fig = plt.figure(figsize=(16, 16))
columns = 4
rows = 5

# Loop through the animals and display images
for i in range(1, len(animals_list) + 1):
    # Construct the full path to the image
    img_path = os.path.join(dataset_path, animals_list[i-1], animals_file_list[i-1][0])

    # Check if the image file exists
    if not os.path.exists(img_path):
        print(f"File not found: {img_path}")
        continue  # Skip this iteration if the file doesn't exist

    # Load the image using its new path
    img = Image.open(img_path)

    # Apply transformations: Resize to 256x256
    compose = transforms.Compose([
        transforms.Resize((256, 256)),
        transforms.ToTensor()  # Convert to tensor for compatibility with PIL
    ])
    img = compose(img)

    # Plot each image
    fig.add_subplot(rows, columns, i)
    plt.axis('off')
    plt.title(animals_list[i-1])
    plt.imshow(img.permute(1, 2, 0))  # Re-order dimensions for displaying (channels first to channels last)

plt.show()

# %% [markdown]
# Very beautiful animals right?

# %% [markdown]
# ## Load Data
#
# Now we will make use of Pytorch elements `transform`, `ImageFolder`, `DataLoader` to load the data.
#
# The next steps will be the following.
#
# 1. Create a dataframe with the name of each file, the animal and the absolute path.
# 2. Select files that will further be in the train, test and validation sets.
# 3. Perform transformation in the data such as reshaping, croping and rotation that will allow the images that are from different sizes to be analyzed together.
# 4. Load the datasets using the DataLoader function, that will transform the images in tensors that will be analysed by the CNN.

# %%
dir = '/content/gdrive/My Drive/oregon_wildlife'
files = [f for f in glob(dir + "**/**", recursive=True)] # create a list will allabsolute path of all files

# %%
# !pip install pandas
import pandas as pd
from glob import glob

dir = './oregon_wildlife' # Modified path to the dataset directory
files = [f for f in glob(dir + "/**/*", recursive=True)] # create a list will allabsolute path of all files

df_animals = pd.DataFrame({"file_path":files}) # transform in a dataframe
df_animals['animal'] = df_animals['file_path'].str.extract(r'oregon_wildlife/(.+?)/') # extract the name of the animal using regex
df_animals['file'] = df_animals['file_path'].str.extract(r'oregon_wildlife/.+/(.+)') # extrat the file name using regex
df_animals = df_animals.dropna() # drop nas

# %% [markdown]
# Now we split the data in train, test and validation (inside the dataframe).

# %%
animal_set = set(df_animals['animal'])
train_val_test_list = [0,1,2]
train_val_weights = [70,15,15]
df_animals['train_val_test'] = 'NA'

for an in animal_set:
  n = sum(df_animals['animal'] == an) # count the number of animals
  train_val_test = random.choices(train_val_test_list, weights= train_val_weights,  k=n)
  df_animals.loc[df_animals['animal'] == an, 'train_val_test'] = train_val_test

# %% [markdown]
# Now we will create the dictonary `transform`. it will be used to transform the train, test and validation datasets.
# We will apply different transformations on the train and test/validation datasets. Data augmentation is used in the trainning dataset to avoid overfitting, that means to avoid the a very good performance on the trainning set but a bed performane on the validation and testing datasets (bed generalization). The methods used were:
# - Flipping the images horizontally
# - Random Cropping: Extract randomly a 224 × 224 pixels section from 256 × 256 pixels
# - RandomRotation: Randomly rotate the image by 10 degrees.

# %%
transform = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'valid': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
}

# %% [markdown]
# We create an auxiliary function to make sure the data is correctly splited among train, test and validation.

# %%
def check_train(path):
    return (df_animals[df_animals['file_path'] == path].train_val_test == 0).bool

def check_valid(path):
    return (df_animals[df_animals['file_path'] == path].train_val_test == 1).bool

def check_test(path):
    return (df_animals[df_animals['file_path'] == path].train_val_test == 2).bool

# %% [markdown]
# #### Load the dataset

# %%
# Reading Dataset
image_datasets = {
    'train' : ImageFolder(root= dir, transform=transform['train'], is_valid_file=check_train),
    'valid' : ImageFolder(root=dir, transform=transform['valid'], is_valid_file=check_valid),
    'test' : ImageFolder(root=dir, transform=transform['test'], is_valid_file=check_test)
}

# %%
num_workers = 0
batch_size = 50

loaders_scratch = {
    'train' : DataLoader(image_datasets['train'], shuffle = True, batch_size = batch_size),
    'valid' : DataLoader(image_datasets['valid'], shuffle = True, batch_size = batch_size),
    'test' : DataLoader(image_datasets['test'], shuffle = True, batch_size = batch_size)
}

# %% [markdown]
# #### USE GPU

# %%
# check if CUDA is available
use_cuda = torch.cuda.is_available()

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Create a CNN to Classify Wild Animals (from Scratch)
#
# We create a CNN that reveives tensors of `224 x 224 x 3` dimensions (that's how we prepared the dataset).
#
# Some of the elements of our network built from scratch.
# - Five convolutional layers. The last will return a tensor of `128 x 256, x 3` dimensions. Padding equals 1.
# - A relu function applied after every convolutional iteration.
# - A pooling function applied after every convolutional iteration.
# - Two dropout layers to avoid overffiting.
# - Two fully connected layers.
#
#
#
#
#  that will transform `128 x 256 x 3`
# - relu

# %%
import torch.nn as nn
import torch.nn.functional as F

# define the CNN architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # convolutional layer (sees 224 x 224 x 3 image tensor)
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        # convolutional layer (sees 122 x 122 x 16 tensor)
        self.conv2 = nn.Conv2d(16, 32, 3, padding=1)
        # convolutional layer (sees 56 x 56 x 32 tensor)
        self.conv3 = nn.Conv2d(32, 64, 3, padding=1)
        # convolutional layer (sees 28 x 28 x 64 tensor)
        self.conv4 = nn.Conv2d(64, 128, 3, padding=1)
        # convolutional layer (sees 14 x 14 x 128 tensor)
        self.conv5 = nn.Conv2d(128, 256, 3, padding=1)

        # max pooling layer
        self.pool = nn.MaxPool2d(2, 2)
        # dropout layer (p=0.25)
        self.dropout = nn.Dropout(0.25)

        self.conv_bn1 = nn.BatchNorm2d(224,3)
        self.conv_bn2 = nn.BatchNorm2d(16)
        self.conv_bn3 = nn.BatchNorm2d(32)
        self.conv_bn4 = nn.BatchNorm2d(64)
        self.conv_bn5 = nn.BatchNorm2d(128)
        self.conv_bn6 = nn.BatchNorm2d(256)

        # linear layer (64 * 4 * 4 -> 133)
        self.fc1 = nn.Linear(256 * 7 * 7, 512)
        # linear layer (133 -> 133)
        self.fc2 = nn.Linear(512, 20)


    def forward(self, x):
        # add sequence of convolutional and max pooling layers
        x = self.conv_bn2(self.pool(F.relu(self.conv1(x))))
        x = self.conv_bn3(self.pool(F.relu(self.conv2(x))))
        x = self.conv_bn4(self.pool(F.relu(self.conv3(x))))
        x = self.conv_bn5(self.pool(F.relu(self.conv4(x))))
        x = self.conv_bn6(self.pool(F.relu(self.conv5(x))))
        # flatten image input
        x = x.view(-1, 256 * 7 * 7)
        # add dropout layer
        x = self.dropout(x)
        # add 1st hidden layer, with relu activation function
        x = F.relu(self.fc1(x))
        # add dropout layer
        x = self.dropout(x)
        # add 2nd hidden layer, with relu activation function
        x = self.fc2(x)
        return x

#-#-# You so NOT have to modify the code below this line. #-#-#

# instantiate the CNN
model_scratch = Net()
print(model_scratch)

# move tensors to GPU if CUDA is available
if use_cuda:
    model_scratch.cuda()

# %% [markdown]
# We define an optmizer and a loss function.
#
# - **loss function**: Cross-entropy loss, or log loss, measures the performance of a classification model whose output is a probability value between 0 and 1. Cross-entropy loss increases as the predicted probability diverges from the actual label. So predicting a probability of .012 when the actual observation label is 1 would be bad and result in a high loss value. A perfect model would have a log loss of 0. From the [ml-cheatsheet](https://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html)
#
# - **optimizer**: Stochastic gradient descent (often abbreviated SGD) is an iterative method for optimizing an objective function with suitable smoothness properties (e.g. differentiable or subdifferentiable). It can be regarded as a stochastic approximation of gradient descent optimization, since it replaces the actual gradient (calculated from the entire data set) by an estimate thereof (calculated from a randomly selected subset of the data). Especially in high-dimensional optimization problems this reduces the computational burden, achieving faster iterations in trade for a lower convergence rate. From [wikipedia](https://en.wikipedia.org/wiki/Stochastic_gradient_descent)

# %%
# specify loss function
criterion_scratch = nn.CrossEntropyLoss()

# specify optimizer
optimizer_scratch = optim.SGD(model_scratch.parameters(), lr=0.001, momentum=0.9)

# %%
def train(n_epochs, loaders, model, optimizer, criterion, use_cuda, save_path):

    """returns trained model"""
    # initialize tracker for minimum validation loss
    valid_loss_min = np.Inf

    for epoch in range(1, n_epochs+1):
        # initialize variables to monitor training and validation loss
        train_loss = 0.0
        valid_loss = 0.0

        ###################
        # train the model #
        ###################
        model.train()
        for batch_idx, (data, target) in enumerate(loaders['train']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## find the loss and update the model parameters accordingly
            ## record the average training loss, using something like
            ## train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            optimizer.zero_grad()
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # backward pass: compute gradient of the loss with respect to model parameters
            loss.backward()
            # perform a single optimization step (parameter update)
            optimizer.step()
            # update training loss
            ## record the average training loss, using something like
            train_loss = train_loss + (1 / (batch_idx + 1)) * (loss.data - train_loss)


        ######################
        # validate the model #
        ######################
        model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):
            # move to GPU
            if use_cuda:
                data, target = data.cuda(), target.cuda()
            ## update the average validation loss
            # forward pass: compute predicted outputs by passing inputs to the model
            output = model(data)
            # calculate the batch loss
            loss = criterion(output, target)
            # update average validation loss
            valid_loss = valid_loss + (1 / (batch_idx + 1)) * (loss.data - valid_loss)


        # print training/validation statistics
        print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
            epoch,
            train_loss,
            valid_loss
            ))

        ## TODO: save the model if validation loss has decreased
        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), '/content/gdrive/My Drive/model_scratch.pt')
            valid_loss_min = valid_loss

    # return trained model
    return model

# train the model
model_scratch = train(25, loaders_scratch, model_scratch, optimizer_scratch, criterion_scratch, use_cuda, 'model_scratch.pt')

# load the model that got the best validation accuracy
model_scratch.load_state_dict(torch.load('/content/gdrive/My Drive/model_scratch.pt'))
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch: 1 	Training Loss: 0.088085 	Validation Loss: 0.030234
# Validation loss decreased (inf --> 0.030234).  Saving model ...
# Epoch: 2 	Training Loss: 0.000973 	Validation Loss: 0.018603
# Validation loss decreased (0.030234 --> 0.018603).  Saving model ...
# Epoch: 3 	Training Loss: 0.000654 	Validation Loss: 0.012961
# Validation loss decreased (0.018603 --> 0.012961).  Saving model ...
# Epoch: 4 	Training Loss: 0.000458 	Validation Loss: 0.010354
# Validation loss decreased (0.012961 --> 0.010354).  Saving model ...
# Epoch: 5 	Training Loss: 0.000359 	Validation Loss: 0.008294
# Validation loss decreased (0.010354 --> 0.008294).  Saving model ...
# Epoch: 6 	Training Loss: 0.000263 	Validation Loss: 0.007032
# Validation loss decreased (0.008294 --> 0.007032).  Saving model ...
# Epoch: 7 	Training Loss: 0.000242 	Validation Loss: 0.005830
# Validation loss decreased (0.007032 --> 0.005830).  Saving model ...
# Epoch: 8 	Training Loss: 0.000218 	Validation Loss: 0.005224
# Validation loss decreased (0.005830 --> 0.005224).  Saving model ...
# Epoch: 9 	Training Loss: 0.000174 	Validation Loss: 0.004687
# Validation loss decreased (0.005224 --> 0.004687).  Saving model ...
# Epoch: 10 	Training Loss: 0.000171 	Validation Loss: 0.004296
# Validation loss decreased (0.004687 --> 0.004296).  Saving model ...
# Epoch: 11 	Training Loss: 0.000140 	Validation Loss: 0.003857
# Validation loss decreased (0.004296 --> 0.003857).  Saving model ...
# Epoch: 12 	Training Loss: 0.000143 	Validation Loss: 0.003599
# Validation loss decreased (0.003857 --> 0.003599).  Saving model ...
# Epoch: 13 	Training Loss: 0.000125 	Validation Loss: 0.003263
# Validation loss decreased (0.003599 --> 0.003263).  Saving model ...
# Epoch: 14 	Training Loss: 0.000113 	Validation Loss: 0.003062
# Validation loss decreased (0.003263 --> 0.003062).  Saving model ...
# Epoch: 15 	Training Loss: 0.000100 	Validation Loss: 0.002748
# Validation loss decreased (0.003062 --> 0.002748).  Saving model ...
# Epoch: 16 	Training Loss: 0.000086 	Validation Loss: 0.002659
# Validation loss decreased (0.002748 --> 0.002659).  Saving model ...
# Epoch: 17 	Training Loss: 0.000080 	Validation Loss: 0.002616
# Validation loss decreased (0.002659 --> 0.002616).  Saving model ...
# Epoch: 18 	Training Loss: 0.000081 	Validation Loss: 0.002496
# Validation loss decreased (0.002616 --> 0.002496).  Saving model ...
# Epoch: 19 	Training Loss: 0.000089 	Validation Loss: 0.002280
# Validation loss decreased (0.002496 --> 0.002280).  Saving model ...
# Epoch: 20 	Training Loss: 0.000079 	Validation Loss: 0.002177
# Validation loss decreased (0.002280 --> 0.002177).  Saving model ...
# Epoch: 21 	Training Loss: 0.000067 	Validation Loss: 0.002066
# Validation loss decreased (0.002177 --> 0.002066).  Saving model ...

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images.  Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 10%.

# %%
def test(loaders, model, criterion, use_cuda):

    # monitor test loss and accuracy
    test_loss = 0.
    correct = 0.
    total = 0.

    model.eval()
    if torch.cuda.is_available():
      model.cuda()
    for batch_idx, (data, target) in enumerate(loaders['test']):
        # move to GPU
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update average test loss
        test_loss = test_loss + ((1 / (batch_idx + 1)) * (loss.data - test_loss))
        # convert output probabilities to predicted class
        pred = output.data.max(1, keepdim=True)[1]
        # compare predictions to true label
        correct += np.sum(np.squeeze(pred.eq(target.data.view_as(pred))).cpu().numpy())
        total += data.size(0)

    print('Test Loss: {:.6f}\n'.format(test_loss))

    print('\nTest Accuracy: %2d%% (%2d/%2d)' % (
        100. * correct / total, correct, total))

# call test function
test(loaders_scratch, model_scratch, criterion_scratch, use_cuda)

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Wild Animals (using Transfer Learning)
#
# We will now use transfer learning to create a CNN that can identify the animals from the images.
#
# From [neurohive](https://neurohive.io/en/popular-networks/vgg16/):
# *VGG16 is a convolutional neural network model proposed by K. Simonyan and A. Zisserman from the University of Oxford in the paper “Very Deep Convolutional Networks for Large-Scale Image Recognition”. The model achieves 92.7% top-5 test accuracy in ImageNet, which is a dataset of over 14 million images belonging to 1000 classes. It was one of the famous model submitted to ILSVRC-2014. It makes the improvement over AlexNet by replacing large kernel-sized filters (11 and 5 in the first and second convolutional layer, respectively) with multiple 3×3 kernel-sized filters one after another. VGG16 was trained for weeks and was using NVIDIA Titan Black GPU’s.*

# %%
## TODO: Specify data loaders
loaders_transfer = loaders_scratch

# %%
import torchvision.models as models
import torch.nn as nn

model_transfer = models.vgg16(pretrained=True)

for param in model_transfer.features.parameters():
    param.requires_grad = False

n_inputs = model_transfer.classifier[6].in_features
last_layer = nn.Linear(n_inputs, 133)
model_transfer.classifier[6] = last_layer


# if GPU is available, move the model to GPU
if use_cuda:
    model_transfer.cuda()
print(model_transfer)

# %%
criterion_transfer = nn.CrossEntropyLoss()
optimizer_transfer = optim.SGD(model_transfer.classifier.parameters(), lr=0.001)

# %%
# train the model
model_transfer = train(25, loaders_transfer, model_transfer, optimizer_transfer, criterion_transfer, use_cuda, 'model_transfer.pt')

# %%
model_transfer.load_state_dict(torch.load('/content/gdrive/My Drive/model_scratch.pt'))

# %%
test(loaders_transfer, model_transfer, criterion_transfer, use_cuda)

# %%
### TODO: Write a function that takes a path to an image as input
### and returns the animal that is predicted by the model.

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from torch.autograd import Variable
import random
import re

# create a list with a class names
class_names = image_datasets['train'].classes
class_names = [re.sub("\d{3}.", "", item) for item in class_names]
class_names = [re.sub("_", " ", item) for item in class_names]

def predict_breed_transfer(img_path):

    # load the image and return the predicted breed
    img = Image.open(img_path) # Load the image from provided path

    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
    )

    preprocess = transforms.Compose([
        transforms.Resize(224),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        normalize]
    )

    img_tensor = preprocess(img).float()
    img_tensor.unsqueeze_(0)  # Insert the new axis at index 0 i.e. in front of the other axes/dims.
    img_tensor = Variable(img_tensor) #The input to the network needs to be an autograd Variable

    if use_cuda:
        img_tensor = Variable(img_tensor.cuda())

    model_transfer.eval()
    output = model_transfer(img_tensor) # Returns a Tensor of shape (batch, num class labels)
    output = output.cpu()

    # Our prediction will be the index of the class label with the largest value.
    predict_index = output.data.numpy().argmax()

    predicted_breed = class_names[predict_index]
    true_breed = image_datasets['train'].classes[predict_index]

    return (predicted_breed, true_breed)

# Create list of test image paths
test_img_paths = list(df_animals[df_animals.train_val_test == 2].file_path)
np.random.shuffle(test_img_paths)

for img_path in test_img_paths[0:20]:
    predicted_breed, true_breed = predict_breed_transfer(img_path)
    print("Predicted Animal:" , predicted_breed, "\n", "True Animal:" , true_breed)
    img=mpimg.imread(img_path)
    imgplot = plt.imshow(img)
    plt.show()
